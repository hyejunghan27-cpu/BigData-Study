# %% [markdown]
# <a href="https://colab.research.google.com/github/hyejunghan27-cpu/BigData-Study/blob/main/ch2_pandas_inf_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 판다스

# %% [markdown]
# ## Section1. 데이터프레임과 시리즈

# %%
# 판다스 라이브러리 불러오기
import pandas as pd

# %%
# 시리즈 만들기 (문자열)
# menu = pd.Series(['a','b','c'])
menu = pd.Series(['비빔밥', '김치찌개', '된장찌개'])
menu
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# dtype: object

# %%
# 시리즈 만들기(정수형)
price = pd.Series([10000, 9000, 8000])
price
# Out:
# 0    10000
# 1     9000
# 2     8000
# dtype: int64

# %%
# 데이터 프레임 만들기 pd.DataFrame({"컬럼명":데이터})
# pd.Dataframe({"컬럼명": 리스트, "컬럼명2": 리스트2})
pd.DataFrame({
    "메뉴" : menu,
    "가격" : price
})
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
# 데이터 프레임 만들기 pd.DataFrame({"컬럼명":데이터})
df = pd.DataFrame({
    "메뉴":['비빔밥', '김치찌개', '된장찌개'],
    "가격":[10000, 9000, 8000],
    "원산지":['국내산', '국내산', '국내산']
})
df
# Out:
#      메뉴     가격  원산지
# 0   비빔밥  10000  국내산
# 1  김치찌개   9000  국내산
# 2  된장찌개   8000  국내산

# %%
# 시리즈 선택 (메뉴)
# 데이터프레임에서 대괄호 하나 -> 시리즈
df['메뉴']
type(df['메뉴'])
# Out:
# pandas.core.series.Series

# %%
# 데이터프레임 선택 (메뉴)
# 데이터프레임에서 대괄호 하나 -> 데이터프레임
df[['메뉴']]
# Out:
#      메뉴
# 0   비빔밥
# 1  김치찌개
# 2  된장찌개

# %%
# 데이터프레임 선택 (메뉴, 가격)
df[['메뉴', '가격']]
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
# 데이터프레임 선택 (메뉴, 가격)
# df[시리즈] -> 데이터프레임
cols = ['메뉴', '가격']
df[cols]
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
# 데이터 프레임 type 확인
print("df          : ", type(df))
print("df['가격']   : ", type(df['가격']))
print("df[['가격']] : ", type(df[['가격']]))
# Out:
# df          :  <class 'pandas.core.frame.DataFrame'>
# df['가격']   :  <class 'pandas.core.series.Series'>
# df[['가격']] :  <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Section2. 데이터 저장 및 불러오기

# %%
# 데이터 준비
df = pd.DataFrame({
    "메뉴":['아메리카노', '카페라떼', '카페모카', '카푸치노', '에스프레소', '밀크티', '녹차'],
    "가격":[4500, 5000, 5500, 5000, 4000, 5900, 5300],
    "칼로리":[10, 110, 250, 110, 20, 210, 0],
})
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
# 저장 temp.csv
df.to_csv('temp.csv')

# %%
# 저장한 데이터 불러오기
# 데이터프레임을 csv로 저장할때 자동으로 인덱스와 같이 저장하게 된다.
temp_df = pd.read_csv('temp.csv')
temp_df.head()
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 0           0  아메리카노  4500   10
# 1           1   카페라떼  5000  110
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20

# %%
# 데이터 불러오기
# df.to_csv('파일명', index=False)
# 인덱싱 없이 csv로 파일 저장
df.to_csv('cafe.csv', index=False)
df = pd.read_csv('cafe.csv')
df.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %% [markdown]
# ## Section3. 탐색적 데이터 분석(EDA)

# %%
# 데이터 샘플 확인: 앞에서 부터 n개 (기본 5개)
df.head(2)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110

# %%
# 데이터 샘플 확인: 뒤에서 부터 n개 (기본 5개)
df.tail(3)
# Out:
#       메뉴    가격  칼로리
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
# sample(랜덤)
df.sample(3)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 2   카페모카  5500  250
# 4  에스프레소  4000   20

# %%
# 데이터 프레임 크기 (행, 컬럼)
df.shape
# Out:
# (7, 3)

# %%
# 컬럼 형태(type)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
# 상관관계
df.corr(numeric_only=True)
# Out:
#            가격       칼로리
# 가격   1.000000  0.713227
# 칼로리  0.713227  1.000000

# %%
# 중복 값이 있는 데이터 생성
df_car = pd.DataFrame({
    "car":['Sedan','SUV','Sedan','SUV','SUV','SUV','Sedan','Sedan','Sedan','Sedan','Sedan'],
    "size":['S','M','S','S','M','M','L','S','S', 'M','S']
})
df_car.head(3)
# Out:
#      car size
# 0  Sedan    S
# 1    SUV    M
# 2  Sedan    S

# %%
# 항목 종류 수
# 데이터프레임은 nunique(), 시리즈는 unique()
df_car.nunique()
# Out:
# car     2
# size    3
# dtype: int64

# %%
# 항목 종류
print(df_car['car'].unique())
print(df_car['size'].unique())
# Out:
# ['Sedan' 'SUV']
# ['S' 'M' 'L']

# %%
# 항목별 개수(value_counts())
# s 붙은거 꼭 기억하기
print(df_car['car'].value_counts())
print(df_car['size'].value_counts())
# Out:
# car
# Sedan    7
# SUV      4
# Name: count, dtype: int64
# size
# S    6
# M    4
# L    1
# Name: count, dtype: int64

# %%
# 기초 통계 (숫자)
df.describe()
# Out:
#                 가격         칼로리
# count     7.000000    7.000000
# mean   5028.571429  101.428571
# std     631.702160   99.402980
# min    4000.000000    0.000000
# 25%    4750.000000   15.000000
# 50%    5000.000000  110.000000
# 75%    5400.000000  160.000000
# max    5900.000000  250.000000

# %%
# 기초 통계 (문자)
# describe
# include="O(대문자 O)"
df_car.describe(include="O")
# Out:
#           car size
# count      11   11
# unique      2    3
# top     Sedan    S
# freq        7    6

# %%
# 기초 통계 (문자)
df.describe(include="O")
# Out:
#            메뉴
# count       7
# unique      7
# top     아메리카노
# freq        1

# %% [markdown]
# ## Section4. 자료형 변환

# %%
# 데이터 준비
data = {
    "메뉴":['아메리카노', '카페라떼', '카페모카', '카푸치노', '에스프레소', '밀크티', '녹차'],
    "가격":[4500.0, 5000.0, 5500.0, 5000.0, 4000.0, 5900.0, 5300.0],
    "칼로리":['10', '110', '250', '110', '20', '210', '0'],
}
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      float64
#  2   칼로리     7 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 300.0+ bytes

# %%
# 자료형 변환 / astype /  float -> int
# df에서 바로 변경하기
# astype('int'): 소수점 절삭
# info
df['가격'] = df['가격'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
# 자료형 변환 / astype /  object -> float
df['칼로리'] = df['칼로리'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 300.0+ bytes

# %% [markdown]
# ## Section5. 새로운 컬럼 추가

# %%
# 데이터 불러오기
df = pd.read_csv('cafe.csv')
df.head(2)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110

# %%
# 새로운 컬럼 추가 (값은 0)
# 'new' 컬럼이 모두 0으로 채워짐
df['new'] = 0
df.head(2)
# Out:
#       메뉴    가격  칼로리  new
# 0  아메리카노  4500   10    0
# 1   카페라떼  5000  110    0

# %%
# 할인가 컬럼 추가
discount = 0.2
df['할인가'] = df['가격'] * (1-discount)
df.head(2)
# Out:
#       메뉴    가격  칼로리  new     할인가
# 0  아메리카노  4500   10    0  3600.0
# 1   카페라떼  5000  110    0  4000.0

# %% [markdown]
# ## Section6. 데이터 삭제 (컬럼, 행)

# %%
# 데이터 불러오기
df = pd.read_csv('cafe.csv')
df.head(3)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250

# %% [markdown]
# ### 행 삭제

# %%
# 행 삭제
# axis=0: 행 삭제
df = df.drop(1, axis=0)
df.head(3)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 2   카페모카  5500  250
# 3   카푸치노  5000  110

# %% [markdown]
# ### 컬럼 삭제

# %%
# 데이터 삭제
# axis=0:행방향, axis=1:열방향(컬럼)
df = df.drop('칼로리', axis=1)
df.head(3)
# Out:
#       메뉴    가격
# 0  아메리카노  4500
# 2   카페모카  5500
# 3   카푸치노  5000

# %% [markdown]
# ## Section7. 인덱싱/슬라이싱(loc)
# - 인덱스 명
# - 인덱스 명(범위), 컬럼 명(범위)

# %%
# 데이터 불러오기
df = pd.read_csv('cafe.csv')
df.head(2)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110

# %%
# 인덱싱 (행 전체)
# 아메리카노
# loc: 명칭으로 선택, iloc: 인덱스 번호로 선택
df.loc[0]
# Out:
# 메뉴     아메리카노
# 가격      4500
# 칼로리       10
# Name: 0, dtype: object

# %%
# 카페라떼 가격
df.loc[1, "가격"]
# Out:
# np.int64(5000)

# %%
# 슬라이싱 (컬럼 전체)
# 가격
df.loc[:, "가격"]
# Out:
# 0    4500
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
# 슬라이싱
df.loc[2, '메뉴':'칼로리']
# Out:
# 메뉴     카페모카
# 가격     5500
# 칼로리     250
# Name: 2, dtype: object

# %%
# 슬라이싱
# 카페모카 메뉴와 칼로리
df.loc[2, ['메뉴', '칼로리']]
# Out:
# 메뉴     카페모카
# 칼로리     250
# Name: 2, dtype: object

# %%
# 슬라이싱
df.loc[1:3, '메뉴':'가격']
# Out:
#      메뉴    가격
# 1  카페라떼  5000
# 2  카페모카  5500
# 3  카푸치노  5000

# %% [markdown]
# ## Section8. 인덱싱/슬라이싱(iloc)
# - 인덱스 번호
# - 인덱스 번호(범위), 컬럼 번호(범위)

# %%
# 데이터 불러오기
df = pd.read_csv('cafe.csv')
df = df.drop(0, axis=0) # 첫번째 행 삭제
df.head(2)
# Out:
#      메뉴    가격  칼로리
# 1  카페라떼  5000  110
# 2  카페모카  5500  250

# %%
df.loc[1]
# Out:
# 메뉴     카페라떼
# 가격     5000
# 칼로리     110
# Name: 1, dtype: object

# %%
# 인덱싱 (행 전체)
# 카페라떼
df.iloc[0]
# Out:
# 메뉴     카페라떼
# 가격     5000
# 칼로리     110
# Name: 1, dtype: object

# %%
df.loc[:, '가격']
# Out:
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
# 슬라이싱 (컬럼 전체)
# 가격
df.iloc[:, 1]
# Out:
# 1    5000
# 2    5500
# 3    5000
# 4    4000
# 5    5900
# 6    5300
# Name: 가격, dtype: int64

# %%
df.head(3)
# Out:
#      메뉴    가격  칼로리
# 1  카페라떼  5000  110
# 2  카페모카  5500  250
# 3  카푸치노  5000  110

# %%
# # 카푸치노 메뉴와 가격
df.loc[3, '메뉴':'가격']
# Out:
# 메뉴    카푸치노
# 가격    5000
# Name: 3, dtype: object

# %%
df.loc[3, ['메뉴', '칼로리']]
# Out:
# 메뉴     카푸치노
# 칼로리     110
# Name: 3, dtype: object

# %%
# 슬라이싱
# 카푸치노 메뉴와 가격
df.iloc[2, 0:2]
# Out:
# 메뉴    카푸치노
# 가격    5000
# Name: 3, dtype: object

# %%
df
# Out:
#       메뉴    가격  칼로리
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차  5300    0

# %%
# 슬라이싱 (카페모카와 카푸치노의 전체 데이터)
df.iloc[1:3]
# Out:
#      메뉴    가격  칼로리
# 2  카페모카  5500  250
# 3  카푸치노  5000  110

# %%
# loc 슬라이싱 (카페모카와 카푸치노의 전체 데이터)
df.loc[2:3,'메뉴':'칼로리']
# Out:
#      메뉴    가격  칼로리
# 2  카페모카  5500  250
# 3  카푸치노  5000  110

# %% [markdown]
# ## Section9. 데이터 추가/변경

# %%
# 데이터 불러오기
df = pd.read_csv('cafe.csv')
df.head(2)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110

# %%
# 결측값으로 추가, 원두 컬럼을 만들고 결측값(NaN)으로 대입
import numpy as np
df['원산지'] = np.nan
df.head(4)
# Out:
#       메뉴    가격  칼로리  원산지
# 0  아메리카노  4500   10  NaN
# 1   카페라떼  5000  110  NaN
# 2   카페모카  5500  250  NaN
# 3   카푸치노  5000  110  NaN

# %%
# 아메리카노의 원두는 '콜롬비아' 데이터 추가
df.loc[0, "원산지"] = '콜롬비아'
df.loc[2:3, "원산지"] = '과테말라'
df.head(4)
# Out:
# /tmp/ipython-input-1959328268.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '콜롬비아' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[0, "원산지"] = '콜롬비아'
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN
# 2   카페모카  5500  250  과테말라
# 3   카푸치노  5000  110  과테말라

# %%
# 리스트 형태로 데이터(행) 추가
# loc에 인자 하나만 들어가면 '행'을 의미
df.loc['시즌'] = ['크리스마스라떼', 6000, 300, '한국']
df.tail(3)
# Out:
#          메뉴    가격  칼로리  원산지
# 5       밀크티  5900  210  NaN
# 6        녹차  5300    0  NaN
# 시즌  크리스마스라떼  6000  300   한국

# %%
# 딕셔너리 형태로 데이터(행) 추가
df.loc[7] = {'메뉴':'딴짓커피', '가격':2000, '칼로리':20}
df.tail(3)
# Out:
#          메뉴    가격  칼로리  원산지
# 6        녹차  5300    0  NaN
# 시즌  크리스마스라떼  6000  300   한국
# 7      딴짓커피  2000   20  NaN

# %%
# cafe2 저장
# drop axis=0: 행 삭제
df = df.drop("시즌", axis=0)
df.to_csv('cafe2.csv', index=False)

# %% [markdown]
# ## Section10. 정렬

# %%
# 데이터 불러오기
df = pd.read_csv('cafe2.csv')
df.head(2)
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN

# %%
# 인덱스 기준 (기본값 ascending=True)
# 인덱스로 sort: sort_index
# 값으로 sort: sort_values
df.sort_index(ascending=False)
# Out:
#       메뉴    가격  칼로리   원산지
# 7   딴짓커피  2000   20   NaN
# 6     녹차  5300    0   NaN
# 5    밀크티  5900  210   NaN
# 4  에스프레소  4000   20   NaN
# 3   카푸치노  5000  110  과테말라
# 2   카페모카  5500  250  과테말라
# 1   카페라떼  5000  110   NaN
# 0  아메리카노  4500   10  콜롬비아

# %%
# 값 기준 (기본값 ascending=True)
# 메뉴 기준 정렬
df.sort_values('메뉴',ascending=False)
# Out:
#       메뉴    가격  칼로리   원산지
# 3   카푸치노  5000  110  과테말라
# 2   카페모카  5500  250  과테말라
# 1   카페라떼  5000  110   NaN
# 4  에스프레소  4000   20   NaN
# 0  아메리카노  4500   10  콜롬비아
# 5    밀크티  5900  210   NaN
# 7   딴짓커피  2000   20   NaN
# 6     녹차  5300    0   NaN

# %%
# 가격과 메뉴 기준 정렬
# 리스트형태로 멀티소트
# 대입연산자로 저장해야 저장이 됨.
df = df.sort_values(['가격', '메뉴'],ascending=[False, True])
df
# Out:
#       메뉴    가격  칼로리   원산지
# 5    밀크티  5900  210   NaN
# 2   카페모카  5500  250  과테말라
# 6     녹차  5300    0   NaN
# 1   카페라떼  5000  110   NaN
# 3   카푸치노  5000  110  과테말라
# 0  아메리카노  4500   10  콜롬비아
# 4  에스프레소  4000   20   NaN
# 7   딴짓커피  2000   20   NaN

# %%
# 인덱스 새로 만들기 drop=True
# drop=True 안하면 인덱스 새로 추가됨
df = df.reset_index(drop=True)
df
# Out:
#       메뉴    가격  칼로리   원산지
# 0    밀크티  5900  210   NaN
# 1   카페모카  5500  250  과테말라
# 2     녹차  5300    0   NaN
# 3   카페라떼  5000  110   NaN
# 4   카푸치노  5000  110  과테말라
# 5  아메리카노  4500   10  콜롬비아
# 6  에스프레소  4000   20   NaN
# 7   딴짓커피  2000   20   NaN

# %% [markdown]
# ## Section11. 필터링

# %%
# 데이터 불러오기
df = pd.read_csv('cafe2.csv')
df.head(2)
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN

# %%
df['칼로리'] < 50
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7     True
# Name: 칼로리, dtype: bool

# %%
# 1개 조건
# 변수에 조건 저장
cond = df['칼로리'] < 50
df[cond]
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 4  에스프레소  4000   20   NaN
# 6     녹차  5300    0   NaN
# 7   딴짓커피  2000   20   NaN

# %%
# 1개 조건
df[df['칼로리'] < 50]
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 4  에스프레소  4000   20   NaN
# 6     녹차  5300    0   NaN
# 7   딴짓커피  2000   20   NaN

# %%
df[~cond]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN

# %%
# 칼로리 50 이상
cond = df['칼로리'] >= 50
df[cond]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN

# %%
# 2개 이상 일때 (AND)
cond1 = df['가격'] >= 5000
cond2 = df['칼로리'] > 100
df[cond1 & cond2]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN

# %%
# 2개 이상 일때 (OR)
df[cond1 | cond2]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라
# 5   밀크티  5900  210   NaN
# 6    녹차  5300    0   NaN

# %%
# 문자열 1개 조건
# 원두 == 콜롬비아
cond = (df['원산지'] == "과테말라")
df[cond]
# Out:
#      메뉴    가격  칼로리   원산지
# 2  카페모카  5500  250  과테말라
# 3  카푸치노  5000  110  과테말라

# %%
# 문자열과 숫자 조건 (AND)
cond1 = df['원산지'] == "과테말라"
cond2 = df['가격'] <= 5000
df[cond1 & cond2]
# Out:
#      메뉴    가격  칼로리   원산지
# 3  카푸치노  5000  110  과테말라

# %%
# isin
df['메뉴'].isin(['녹차'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# Name: 메뉴, dtype: bool

# %%
# isin 활용
cond = df['메뉴'].isin(['녹차'])
df[cond]
# Out:
#    메뉴    가격  칼로리  원산지
# 6  녹차  5300    0  NaN

# %%
# isin 활요 (복수 컬럼)
box = ['녹차', '카푸치노', '카페라떼']
cond = df['메뉴'].isin(box)
df[cond]
# Out:
#      메뉴    가격  칼로리   원산지
# 1  카페라떼  5000  110   NaN
# 3  카푸치노  5000  110  과테말라
# 6    녹차  5300    0   NaN

# %% [markdown]
# ## Section12. 결측치 처리

# %%
# 데이터 불러오기
df = pd.read_csv('cafe2.csv')
df.head(2)
# Out:
#       메뉴    가격  칼로리   원산지
# 0  아메리카노  4500   10  콜롬비아
# 1   카페라떼  5000  110   NaN

# %%
# 결측치 여부
df.isnull()
# Out:
#       메뉴     가격    칼로리    원산지
# 0  False  False  False  False
# 1  False  False  False   True
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False   True
# 5  False  False  False   True
# 6  False  False  False   True
# 7  False  False  False   True

# %%
# 컬럼별 결측치 확인
# null 여부를 숫자처럼 더하기 가능
df.isnull().sum()
# Out:
# 메뉴     0
# 가격     0
# 칼로리    0
# 원산지    5
# dtype: int64

# %%
# 컬럼별 결측치 확인
# isnull과 isna는 동일
df.isna().sum()
# Out:
# 메뉴     0
# 가격     0
# 칼로리    0
# 원산지    5
# dtype: int64

# %%
# 결측값 채우기
# fillna
df['원산지'] = df['원산지'].fillna('코스타리카')
df
# Out:
#       메뉴    가격  칼로리    원산지
# 0  아메리카노  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6     녹차  5300    0  코스타리카
# 7   딴짓커피  2000   20  코스타리카

# %%
# 저장
df.to_csv("cafe3.csv", index=False)

# %% [markdown]
# ## Section13. 값 변경

# %%
# 데이터 확인
pd.read_csv("cafe3.csv")
df.head(3)
# Out:
#       메뉴    가격  칼로리    원산지
# 0  아메리카노  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라

# %%
# 문자 변경 : 아메리카노 -> 룽고, 녹차 -> 그린티
# replace 함수 쓴 후 반드시 대입해야 데이터 변경됨
df = df.replace('아메리카노', '룽고')
df = df.replace('녹차','그린티')
df
# Out:
#       메뉴    가격  칼로리    원산지
# 0     룽고  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6    그린티  5300    0  코스타리카
# 7   딴짓커피  2000   20  코스타리카

# %%
# 딕셔너리 활용
# 딕셔너리를 통해 한번에 변경
change = {'룽고':'아메리카노', '그린티':'녹차'}
df = df.replace(change)
df
# Out:
#       메뉴    가격  칼로리    원산지
# 0  아메리카노  4500   10   콜롬비아
# 1   카페라떼  5000  110  코스타리카
# 2   카페모카  5500  250   과테말라
# 3   카푸치노  5000  110   과테말라
# 4  에스프레소  4000   20  코스타리카
# 5    밀크티  5900  210  코스타리카
# 6     녹차  5300    0  코스타리카
# 7   딴짓커피  2000   20  코스타리카

# %%
# loc로 값 변경하기
df.loc[6, '원산지'] = '대한민국'
df.tail(3)
# Out:
#      메뉴    가격  칼로리    원산지
# 5   밀크티  5900  210  코스타리카
# 6    녹차  5300    0   대한민국
# 7  딴짓커피  2000   20  코스타리카

# %%
# 이벤트가 전체 1000으로 변경
# loc로 변경하는건 다시 대입 안해도 됨
# 컬럼이 없으면 새로 만듬
df.loc[1:2, '이벤트가'] = 1000
df.head()
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0
# 2   카페모카  5500  250   과테말라  1000.0
# 3   카푸치노  5000  110   과테말라     NaN
# 4  에스프레소  4000   20  코스타리카     NaN

# %%
# 저장
df.to_csv("cafe4.csv", index=False)

# %%
# map() 함수
# 실무에서는 replace 보다는 map 함수를 더 많이 씀
import pandas as pd
df = pd.DataFrame({'만족도': ['만족', '보통' ,'불만', '보통', '만족']})

mapping = {'만족': 3, '보통': 2, '불만': 1}
# 새로운 열 만들기
df['만족도_숫자'] = df['만족도'].map(mapping)
df
# Out:
#   만족도  만족도_숫자
# 0  만족       3
# 1  보통       2
# 2  불만       1
# 3  보통       2
# 4  만족       3

# %% [markdown]
# ## Section14. 문자열

# %%
import pandas as pd
df = pd.DataFrame({'A': ['데이터 분석', '기본 학습서', '퇴근 후 열공'],
                   'B': [10, 20, 30],
                   'C': ['ab cd', 'AB CD', 'ab cd ']
                   })
df
# Out:
#          A   B       C
# 0   데이터 분석  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
# 값 변경 시도
# 문자 일부를 변경하는건 replace만 쓰면 안됨
df['A'] = df['A'].replace('분석', '시각화')
df
# Out:
#          A   B       C
# 0   데이터 분석  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
# 값 변경(str)
# replace 전에 str 써주기
df['A'] = df['A'].str.replace('분석', '시각화')
df
# Out:
#          A   B       C
# 0  데이터 시각화  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
# 값 변경 (숫자)
# 숫자일때는 그냥 replace
df['B'] = df['B'].replace(10, 100)
df
# Out:
#          A    B       C
# 0  데이터 시각화  100   ab cd
# 1   기본 학습서   20   AB CD
# 2  퇴근 후 열공   30  ab cd

# %%
# 에러
# df['B'] = df['B'].str.replace(20, 200)
# print(df)

# %%
# 문자열 분리
df['A'].str.split()
# Out:
# 0     [데이터, 시각화]
# 1      [기본, 학습서]
# 2    [퇴근, 후, 열공]
# Name: A, dtype: object

# %%
# 첫번째 행 데이터
# split 전에 str 붙여주기
df['A'].str.split()[0]
# Out:
# ['데이터', '시각화']

# %%
# 각 행별 첫번째 요소 추출
df['D'] = df['A'].str.split().str[0]
df
# Out:
#          A    B       C    D
# 0  데이터 시각화  100   ab cd  데이터
# 1   기본 학습서   20   AB CD   기본
# 2  퇴근 후 열공   30  ab cd    퇴근

# %%
# 문자 검색
# contains도 마찬가지로 앞에 str 붙여주기
df['A'].str.contains('기본')
# Out:
# 0    False
# 1     True
# 2    False
# Name: A, dtype: bool

# %%
# 문자 포함 여부
# 새로운 열로 붙여주기
df['기본포함유무'] = df['A'].str.contains('기본')
df
# Out:
#          A    B       C    D  기본포함유무
# 0  데이터 시각화  100   ab cd  데이터   False
# 1   기본 학습서   20   AB CD   기본    True
# 2  퇴근 후 열공   30  ab cd    퇴근   False

# %%
# isin
menu = pd.Series(['맛난버거 세트', '매운 치킨버거', '더블 치즈버거'])
menu.isin(['맛난버거 세트', '더블 치즈버거'])
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
# contains
menu.str.contains('세트')
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
# 문자 길이
# 문자길이도 len 앞에 str 붙여주기
df['문자길이'] = df['A'].str.len()
df
# Out:
#          A    B       C    D  기본포함유무  문자길이
# 0  데이터 시각화  100   ab cd  데이터   False     7
# 1   기본 학습서   20   AB CD   기본    True     6
# 2  퇴근 후 열공   30  ab cd    퇴근   False     7

# %%
# 대소문자 구분
'AB cd' == 'ab CD'
# Out:
# False

# %%
# 소문자로 변경
df['C'] = df['C'].str.lower()
df['C']
# Out:
# 0     ab cd
# 1     ab cd
# 2    ab cd
# Name: C, dtype: object

# %%
# 대분자로 변경
df['C'] = df['C'].str.upper()
df['C']
# Out:
# 0     AB CD
# 1     AB CD
# 2    AB CD
# Name: C, dtype: object

# %%
# 공백
df['C'] == 'AB CD'
# Out:
# 0    False
# 1    False
# 2    False
# Name: C, dtype: bool

# %%
# 공백 제거 및 소문자 처리
df['C'] = df['C'].str.lower()
df['C'] = df['C'].str.replace(" ","")
df['C']
# Out:
# 0    abcd
# 1    abcd
# 2    abcd
# Name: C, dtype: object

# %%
# 문자열 슬라이싱
# 각 문자열을 슬라이싱할때는 str을 붙여줘야 함
df['C'].str[1:3]
# Out:
# 0    bc
# 1    bc
# 2    bc
# Name: C, dtype: object

# %%
# 행 선택
df['C'][1:3]
# Out:
# 1    abcd
# 2    abcd
# Name: C, dtype: object

# %% [markdown]
# ## Section15. 내장함수

# %%
# 데이터 불러오기
df = pd.read_csv("cafe4.csv")
df.head(2)
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0

# %%
df.shape
# Out:
# (8, 5)

# %%
# 행의 수
print(len(df))
print(df.shape[0])
print(df.shape[1])
# Out:
# 8
# 8
# 5

# %%
cond = df['가격'] > 5000

# 조건에 맞는 개수 구하기: sum(cond), len(df[cond])

#sum으로 조건에 맞는 개수 구하기
print(sum(cond))

#len으로 조건에 맞는 개수 구하기
print(len(df[cond]))
# Out:
# 3
# 3

# %%
# 합계 (컬럼)
df.sum(numeric_only=True)
# Out:
# 가격      37200.0
# 칼로리       730.0
# 이벤트가     2000.0
# dtype: float64

# %%
# 합계 (행)
# 행별로 합치기: sum(axis=1)
# drop과 반대로 axis가 1일때 행별로 합쳐짐
# drop 0: 행, 1: 컬럼
# sum 0: 컬럼별, 1: 행별
df.sum(axis=1, numeric_only=True)
# Out:
# 0    4510.0
# 1    6110.0
# 2    6750.0
# 3    5110.0
# 4    4020.0
# 5    6110.0
# 6    5300.0
# 7    2020.0
# dtype: float64

# %%
# 최대, 최소, 평균, 중앙, 합계, 표준편차, 분산
print("최대값: ",df['가격'].max())
print("최소값: ",df['가격'].min())
print("평균값: ",df['가격'].mean())
print("중앙값: ",df['가격'].median())
print("합계: ",df['가격'].sum())
print("표준편차: ",df['가격'].std())
print("분산: ",df['가격'].var())
# Out:
# 최대값:  5900
# 최소값:  2000
# 평균값:  4650.0
# 중앙값:  5000.0
# 합계:  37200
# 표준편차:  1220.070255588353
# 분산:  1488571.4285714286

# %%
# 분위수
# quantile(.25) 하위
# quantile(.75) 상위
print("분위수 25% 값", df['가격'].quantile(.25))
print("분위수 75% 값", df['가격'].quantile(.75))
print("분위수 15% 값", df['가격'].quantile(.15))
# Out:
# 분위수 25% 값 4375.0
# 분위수 75% 값 5350.0
# 분위수 15% 값 4025.0

# %%
# 하위 25% 데이터
cond = df['가격'].quantile(.25) > df['가격']
df[cond]
# Out:
#       메뉴    가격  칼로리    원산지  이벤트가
# 4  에스프레소  4000   20  코스타리카   NaN
# 7   딴짓커피  2000   20  코스타리카   NaN

# %%
# 상위 25% 데이터
cond = df['가격'].quantile(.75) < df['가격']
df[cond]
# Out:
#      메뉴    가격  칼로리    원산지    이벤트가
# 2  카페모카  5500  250   과테말라  1000.0
# 5   밀크티  5900  210  코스타리카     NaN

# %%
# 최빈값 구하기
# 최빈값은 시리즈 형태로 반환되기 때문에 [0]을 붙여야 함
df['원산지'].mode()[0]
# Out:
# '코스타리카'

# %%
# 최대값의 인덱스
# idxmax
df['가격'].idxmax()
# Out:
# 5

# %%
# 최대값의 인덱스로 데이터 선택
max_ind = df['가격'].idxmax()
df.loc[max_ind]
# Out:
# 메뉴        밀크티
# 가격       5900
# 칼로리       210
# 원산지     코스타리카
# 이벤트가      NaN
# Name: 5, dtype: object

# %%
# 최대값의 인덱스 활용
# df.loc[인덱스값, '컬럼명']
df.loc[max_ind, '메뉴'] # 추천 방법
# df.loc[max_ind]['메뉴'] # 다른 방법
# Out:
# '밀크티'

# %%
# 가격 컬럼 중 가장 큰 값 3개
# nlargest(숫자, '컬럼명')
df.nlargest(3, '가격')
# Out:
#      메뉴    가격  칼로리    원산지    이벤트가
# 5   밀크티  5900  210  코스타리카     NaN
# 2  카페모카  5500  250   과테말라  1000.0
# 6    녹차  5300    0   대한민국     NaN

# %%
# 가격 컬럼 중 가장 작은 값 2개
# nsmallest(숫자, '컬럼명')
df.nsmallest(2, '가격')
# Out:
#       메뉴    가격  칼로리    원산지  이벤트가
# 7   딴짓커피  2000   20  코스타리카   NaN
# 4  에스프레소  4000   20  코스타리카   NaN

# %%
# apply 적용해서 새로운 컬럼 생성 (칼로리 컬럼 활용)
# df['컬럼명'].apply(함수)
def cal(x):
    if x >= 100:
        return "No"
    else:
        return "Yes"

df['먹어도 될까요'] = df['칼로리'].apply(cal)
df
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가 먹어도 될까요
# 0  아메리카노  4500   10   콜롬비아     NaN     Yes
# 1   카페라떼  5000  110  코스타리카  1000.0      No
# 2   카페모카  5500  250   과테말라  1000.0      No
# 3   카푸치노  5000  110   과테말라     NaN      No
# 4  에스프레소  4000   20  코스타리카     NaN     Yes
# 5    밀크티  5900  210  코스타리카     NaN      No
# 6     녹차  5300    0   대한민국     NaN     Yes
# 7   딴짓커피  2000   20  코스타리카     NaN     Yes

# %%
import pandas as pd
df = pd.DataFrame({'Name': {0: '쿼카', 1: '알파카', 2: '시바견'},
                   '수학': {0: 90, 1: 93, 2: 85},
                   '영어': {0: 92, 1: 84, 2: 86},
                   '국어': {0: 91, 1: 94, 2: 83},})

df
# Out:
#   Name  수학  영어  국어
# 0   쿼카  90  92  91
# 1  알파카  93  84  94
# 2  시바견  85  86  83

# %%
# melt
# 인덱스, id_vars, variable(id vars 외 컬럼이 여기서 일렬로 녹음), value
pd.melt(df, id_vars=['Name'])
# Out:
#   Name variable  value
# 0   쿼카       수학     90
# 1  알파카       수학     93
# 2  시바견       수학     85
# 3   쿼카       영어     92
# 4  알파카       영어     84
# 5  시바견       영어     86
# 6   쿼카       국어     91
# 7  알파카       국어     94
# 8  시바견       국어     83

# %%
# melt - value 선택
# 녹일 변수 선택
# melt(df, id_vars=['컬럼명'], value_vars=['컬럼명'])
pd.melt(df, id_vars=['Name'], value_vars=['수학', '영어'])
# Out:
#   Name variable  value
# 0   쿼카       수학     90
# 1  알파카       수학     93
# 2  시바견       수학     85
# 3   쿼카       영어     92
# 4  알파카       영어     84
# 5  시바견       영어     86

# %%
pd.melt(df, id_vars=['Name'], value_vars=['수학', '영어'], var_name='과목', value_name='점수')
# Out:
#   Name  과목  점수
# 0   쿼카  수학  90
# 1  알파카  수학  93
# 2  시바견  수학  85
# 3   쿼카  영어  92
# 4  알파카  영어  84
# 5  시바견  영어  86

# %%
# melt 컬럼명 설정
# melt(df, id_vars['컬럼명'], var_name='컬럼명', value_name='컬럼명')
pd.melt(df, id_vars=['Name'], var_name='과목', value_name='점수')
# Out:
#   Name  과목  점수
# 0   쿼카  수학  90
# 1  알파카  수학  93
# 2  시바견  수학  85
# 3   쿼카  영어  92
# 4  알파카  영어  84
# 5  시바견  영어  86
# 6   쿼카  국어  91
# 7  알파카  국어  94
# 8  시바견  국어  83

# %%
import pandas as pd

df = pd.DataFrame({
    "반": ["A반", "A반", "B반"],  # 반 정보 추가
    "이름": ["쿼카", "알파카", "시바견"],
    "수학": [90, 93, 85],
    "영어": [92, 84, 86],
    "국어": [91, 94, 83]
})
df
# Out:
#     반   이름  수학  영어  국어
# 0  A반   쿼카  90  92  91
# 1  A반  알파카  93  84  94
# 2  B반  시바견  85  86  83

# %%
# melt 2개 기준
# {반, 이름} 기준으로 var_name이 melt
pd.melt(df, id_vars=["반", "이름"], var_name="과목", value_name="점수")
# Out:
#     반   이름  과목  점수
# 0  A반   쿼카  수학  90
# 1  A반  알파카  수학  93
# 2  B반  시바견  수학  85
# 3  A반   쿼카  영어  92
# 4  A반  알파카  영어  84
# 5  B반  시바견  영어  86
# 6  A반   쿼카  국어  91
# 7  A반  알파카  국어  94
# 8  B반  시바견  국어  83

# %% [markdown]
# ## Section16. 그룹핑

# %%
df = pd.read_csv("cafe4.csv")
df.head(2)
# Out:
#       메뉴    가격  칼로리    원산지    이벤트가
# 0  아메리카노  4500   10   콜롬비아     NaN
# 1   카페라떼  5000  110  코스타리카  1000.0

# %%
# 원산지 기준, 평균
# groupby(['컬럼명'])
# groupby 함수 안에 대괄호 쓰기
df.groupby(['원산지']).mean(numeric_only=True)
# Out:
#            가격    칼로리    이벤트가
# 원산지
# 과테말라   5250.0  180.0  1000.0
# 대한민국   5300.0    0.0     NaN
# 코스타리카  4225.0   90.0  1000.0
# 콜롬비아   4500.0   10.0     NaN

# %%
# 원산지와 칼로리 기준, 평균
df.groupby(['원산지', '칼로리']).mean(numeric_only=True)
# Out:
#                가격    이벤트가
# 원산지   칼로리
# 과테말라  110  5000.0     NaN
#       250  5500.0  1000.0
# 대한민국  0    5300.0     NaN
# 코스타리카 20   3000.0     NaN
#       110  5000.0  1000.0
#       210  5900.0     NaN
# 콜롬비아  10   4500.0     NaN

# %%
# 원산지와 메뉴 기준 (평균, 합계)
# 평균, 합계 다 보고싶을 경우 agg(['mean', 'sum'])
df.groupby(['원산지', '메뉴']).agg(['mean', 'sum'])
# Out:
#                  가격          칼로리         이벤트가
#                mean   sum   mean  sum    mean     sum
# 원산지   메뉴
# 과테말라  카페모카   5500.0  5500  250.0  250  1000.0  1000.0
#       카푸치노   5000.0  5000  110.0  110     NaN     0.0
# 대한민국  녹차     5300.0  5300    0.0    0     NaN     0.0
# 코스타리카 딴짓커피   2000.0  2000   20.0   20     NaN     0.0
#       밀크티    5900.0  5900  210.0  210     NaN     0.0
#       에스프레소  4000.0  4000   20.0   20     NaN     0.0
#       카페라떼   5000.0  5000  110.0  110  1000.0  1000.0
# 콜롬비아  아메리카노  4500.0  4500   10.0   10     NaN     0.0

# %%
df.groupby(['원산지', '메뉴']).agg(['mean', 'sum']).reset_index()
# Out:
#      원산지     메뉴      가격          칼로리         이벤트가
#                    mean   sum   mean  sum    mean     sum
# 0   과테말라   카페모카  5500.0  5500  250.0  250  1000.0  1000.0
# 1   과테말라   카푸치노  5000.0  5000  110.0  110     NaN     0.0
# 2   대한민국     녹차  5300.0  5300    0.0    0     NaN     0.0
# 3  코스타리카   딴짓커피  2000.0  2000   20.0   20     NaN     0.0
# 4  코스타리카    밀크티  5900.0  5900  210.0  210     NaN     0.0
# 5  코스타리카  에스프레소  4000.0  4000   20.0   20     NaN     0.0
# 6  코스타리카   카페라떼  5000.0  5000  110.0  110  1000.0  1000.0
# 7   콜롬비아  아메리카노  4500.0  4500   10.0   10     NaN     0.0

# %%
# 1개 인덱스 형태로 리셋
# reset_index: 그룹이 묶여나오는걸 푸는 함수
df.groupby(['원산지', '칼로리']).mean(numeric_only=True).reset_index()
# Out:
#      원산지  칼로리      가격    이벤트가
# 0   과테말라  110  5000.0     NaN
# 1   과테말라  250  5500.0  1000.0
# 2   대한민국    0  5300.0     NaN
# 3  코스타리카   20  3000.0     NaN
# 4  코스타리카  110  5000.0  1000.0
# 5  코스타리카  210  5900.0     NaN
# 6   콜롬비아   10  4500.0     NaN

# %%
# transform
import pandas as pd

# 데이터 생성 (일부 결측값 포함)
df = pd.DataFrame({
    '과일': ['딸기', '블루베리', '딸기', '블루베리', '딸기', '블루베리', '딸기', '블루베리'],
    '가격': [1000, None, 1500, None, 2000, 2500, None, 1800]  # 결측값 포함
})
df
# Out:
#      과일      가격
# 0    딸기  1000.0
# 1  블루베리     NaN
# 2    딸기  1500.0
# 3  블루베리     NaN
# 4    딸기  2000.0
# 5  블루베리  2500.0
# 6    딸기     NaN
# 7  블루베리  1800.0

# %%
# 과일/등급별 평균 가격 구하기
# 각 행별로 과일의 가격 평균 구하기: transform("mean")
# df.groupby('그룹핑할 컬럼')['타겟 컬럼'].transform("mean")
price = df.groupby('과일')['가격'].transform("mean")
print(type(price))
price
# Out:
# <class 'pandas.core.series.Series'>
# 0    1500.0
# 1    2150.0
# 2    1500.0
# 3    2150.0
# 4    1500.0
# 5    2150.0
# 6    1500.0
# 7    2150.0
# Name: 가격, dtype: float64

# %%
# 결측치 채우기
# fillna(transform 결과(Series))
# 결측값이 있는 부분만 채워짐
df['가격'] = df['가격'].fillna(price)
df
# Out:
#      과일      가격
# 0    딸기  1000.0
# 1  블루베리  2150.0
# 2    딸기  1500.0
# 3  블루베리  2150.0
# 4    딸기  2000.0
# 5  블루베리  2500.0
# 6    딸기  1500.0
# 7  블루베리  1800.0

# %%
df = pd.DataFrame({
    '과일': ['딸기', '블루베리', '딸기', '블루베리', '딸기', '블루베리', '딸기', '블루베리'],
    '등급': ['B', 'B', 'A', 'A', 'A', 'A', 'B', 'B'],  # 새로운 그룹 추가
    '가격': [1000, None, 1500, None, 2000, 2500, None, 1800]  # 결측값 포함
})
df
# Out:
#      과일 등급      가격
# 0    딸기  B  1000.0
# 1  블루베리  B     NaN
# 2    딸기  A  1500.0
# 3  블루베리  A     NaN
# 4    딸기  A  2000.0
# 5  블루베리  A  2500.0
# 6    딸기  B     NaN
# 7  블루베리  B  1800.0

# %%
# 과일/등급별 평균 가격 구하기
# df.groupby(['컬럼', '컬럼'])['타겟'].transform("mean")
price = df.groupby(['과일', '등급'])['가격'].transform("mean")
price
# Out:
# 0    1000.0
# 1    1800.0
# 2    1750.0
# 3    2500.0
# 4    1750.0
# 5    2500.0
# 6    1000.0
# 7    1800.0
# Name: 가격, dtype: float64

# %%
# 결측치 채우기
df['가격'] = df['가격'].fillna(price)
df
# Out:
#      과일 등급      가격
# 0    딸기  B  1000.0
# 1  블루베리  B  1800.0
# 2    딸기  A  1500.0
# 3  블루베리  A  2500.0
# 4    딸기  A  2000.0
# 5  블루베리  A  2500.0
# 6    딸기  B  1000.0
# 7  블루베리  B  1800.0

# %%
# unstack
import pandas as pd

coffee_data = {
    '커피종류': ['아메리카노', '아메리카노', '아메리카노', '라떼', '라떼', '라떼'],
    '컵크기': ['Small', 'Medium', 'Large', 'Small', 'Medium', 'Large'],
    '판매량': [120, 150, 200, 100, 130, 180]
}
df = pd.DataFrame(coffee_data)
df
# Out:
#     커피종류     컵크기  판매량
# 0  아메리카노   Small  120
# 1  아메리카노  Medium  150
# 2  아메리카노   Large  200
# 3     라떼   Small  100
# 4     라떼  Medium  130
# 5     라떼   Large  180

# %%
# groupby 적용
grouped = df.groupby(['커피종류', '컵크기'])['판매량'].sum()
grouped
# Out:
# 커피종류   컵크기
# 라떼     Large     180
#        Medium    130
#        Small     100
# 아메리카노  Large     200
#        Medium    150
#        Small     120
# Name: 판매량, dtype: int64

# %%
# 컵크기를 컬럼으로 변환
grouped.unstack()
# Out:
# 컵크기    Large  Medium  Small
# 커피종류
# 라떼       180     130    100
# 아메리카노    200     150    120

# %%
grouped.unstack(level=-1)
# default level이 -1임.
# Out:
# 컵크기    Large  Medium  Small
# 커피종류
# 라떼       180     130    100
# 아메리카노    200     150    120

# %%
# 커피종류를 컬럼으로 변환
grouped.unstack(level=0)
# Out:
# 커피종류     라떼  아메리카노
# 컵크기
# Large   180    200
# Medium  130    150
# Small   100    120

# %%
# 두 번의 unstack 적용
# unstack 두번 쓰면 그룹 위치가 뒤집힘
grouped.unstack().unstack()
# Out:
# 컵크기     커피종류
# Large   라떼       180
#         아메리카노    200
# Medium  라떼       130
#         아메리카노    150
# Small   라떼       100
#         아메리카노    120
# dtype: int64

# %% [markdown]
# ## Section 17과 18
# - "시계열 데이터" 부분은 마지막으로 옮겼습니다.

# %% [markdown]
# ## Section19. 데이터 합치기

# %%
import pandas as pd

# 에피타이저 메뉴
appetizer = pd.DataFrame({
    'Menu': ['Salad', 'Soup', 'Bread'],
    'Price': [5000, 3000, 2000]
})

# 메인 메뉴
main = pd.DataFrame({
    'Menu': ['Steak', 'Pasta', 'Chicken'],
    'Price': [15000, 12000, 10000]
})
print(appetizer)
print(main)
# Out:
#     Menu  Price
# 0  Salad   5000
# 1   Soup   3000
# 2  Bread   2000
#       Menu  Price
# 0    Steak  15000
# 1    Pasta  12000
# 2  Chicken  10000

# %%
# 두 메뉴를 수직으로 연결
full_menu = pd.concat([appetizer, main], ignore_index=True)
full_menu
# Out:
#       Menu  Price
# 0    Salad   5000
# 1     Soup   3000
# 2    Bread   2000
# 3    Steak  15000
# 4    Pasta  12000
# 5  Chicken  10000

# %%
# 두 메뉴를 좌우로 연결
# concat axis=1: 좌우로 연결
full_menu = pd.concat([appetizer, main], axis=1)
full_menu
# Out:
#     Menu  Price     Menu  Price
# 0  Salad   5000    Steak  15000
# 1   Soup   3000    Pasta  12000
# 2  Bread   2000  Chicken  10000

# %%
# 메뉴와 가격
price = pd.DataFrame({
    'Menu': ['Salad', 'Soup', 'Steak', 'Pasta'],
    'Price': [5000, 3000, 15000, 12000]
})

# 메뉴와 칼로리
cal = pd.DataFrame({
    'Menu': ['Soup', 'Steak', 'Pasta','Salad'],
    'Calories': [100, 500, 400, 150]
})

# 두 데이터프레임을 'Menu'를 기준으로 병합
# pd.merge(df1, df2, on="컬럼명")
menu_info = pd.merge(price, cal, on='Menu')
menu_info
# Out:
#     Menu  Price  Calories
# 0  Salad   5000       150
# 1   Soup   3000       100
# 2  Steak  15000       500
# 3  Pasta  12000       400

# %% [markdown]
# ## Section20.피벗테이블

# %%
import pandas as pd

# 직원별 부서 및 급여 정보
data = {
    '이름': ['서아', '다인', '채아', '예담', '종현', '태헌'],
    '부서': ['개발', '기획', '개발', '기획', '개발', '기획'],
    '급여': [3000, 3200, 3100, 3300, 2900, 3100]
}
df = pd.DataFrame(data)
print("[원본 데이터]")
print(df)

# 부서별 평균 급여 계산
# df.pivot_table(index='행이 될 컬럼', values='타겟컬럼', aggfunc='mean')
pt = df.pivot_table(index='부서', values='급여', aggfunc='mean')
print("\n[부서별 평균 급여]") #\n은 줄 바꿈(새로운 줄 시작)
print(pt)
# Out:
# [원본 데이터]
#    이름  부서    급여
# 0  서아  개발  3000
# 1  다인  기획  3200
# 2  채아  개발  3100
# 3  예담  기획  3300
# 4  종현  개발  2900
# 5  태헌  기획  3100
#
# [부서별 평균 급여]
#         급여
# 부서
# 개발  3000.0
# 기획  3200.0

# %%
# 부서와 직급별 급여 정보
data = {
    '부서': ['개발', '기획', '기획', '기획', '개발', '개발'],
    '직급': ['대리', '과장', '대리', '과장', '대리', '과장'],
    '급여': [3000, 4000, 3200, 4200, 3500, 4500]
}
df = pd.DataFrame(data)
print("[원본 데이터]")
print(df)

# 부서 및 직급별 급여 합계 계산
# df.pivot_table(index='행이 될 컬럼', columns='열이 될 컬럼', values='타겟컬럼', aggfunc='mean')
pt = df.pivot_table(index='부서', columns='직급', values='급여', aggfunc='sum')
print("\n[부서 및 직급별 급여 합계]")
print(pt)
# Out:
# [원본 데이터]
#    부서  직급    급여
# 0  개발  대리  3000
# 1  기획  과장  4000
# 2  기획  대리  3200
# 3  기획  과장  4200
# 4  개발  대리  3500
# 5  개발  과장  4500
#
# [부서 및 직급별 급여 합계]
# 직급    과장    대리
# 부서
# 개발  4500  6500
# 기획  8200  3200

# %%
# 부서와 성별, 근속연수 정보
data = {
    '부서': ['개발', '기획', '기획', '기획', '개발', '개발'],
    '성별': ['남', '여', '남', '여', '남', '여'],
    '근속연수': [3, 5, 4, 6, 7, 8]
}
df = pd.DataFrame(data)
print("[원본 데이터]")
print(df)

# 부서 및 성별 평균 근속연수 계산
pt = df.pivot_table(index='부서', columns='성별', values='근속연수', aggfunc='mean')
print("\n[부서 및 성별 평균 근속연수]")
print(pt)
# Out:
# [원본 데이터]
#    부서 성별  근속연수
# 0  개발  남     3
# 1  기획  여     5
# 2  기획  남     4
# 3  기획  여     6
# 4  개발  남     7
# 5  개발  여     8
#
# [부서 및 성별 평균 근속연수]
# 성별    남    여
# 부서
# 개발  5.0  8.0
# 기획  4.0  5.5

# %%
# 다양한 집계를 위한 데이터셋
import pandas as pd

df = pd.DataFrame({
    "구분": ["전자", "전자", "전자", "전자", "전자", "가전", "가전", "가전", "가전"],
    "유형": ["일반", "일반", "일반", "특수", "특수", "일반", "일반", "특수", "특수"],
    "크기": ["소형", "대형", "대형", "소형", "소형", "대형", "소형", "소형", "대형"],
    "수량": [1, 2, 2, 3, 3, 4, 5, 6, 7],
    "금액": [2, 4, 5, 5, 6, 6, 8, 9, 9]
})
print(df)
# Out:
#    구분  유형  크기  수량  금액
# 0  전자  일반  소형   1   2
# 1  전자  일반  대형   2   4
# 2  전자  일반  대형   2   5
# 3  전자  특수  소형   3   5
# 4  전자  특수  소형   3   6
# 5  가전  일반  대형   4   6
# 6  가전  일반  소형   5   8
# 7  가전  특수  소형   6   9
# 8  가전  특수  대형   7   9

# %%
# 단일 값에 대해 집계
pt = df.pivot_table(
    index=['구분', '유형'],
    columns='크기',
    values='수량',
    aggfunc='sum'
)
pt
# Out:
# 크기      대형   소형
# 구분 유형
# 가전 일반  4.0  5.0
#    특수  7.0  6.0
# 전자 일반  4.0  1.0
#    특수  NaN  6.0

# %%
# 단일 값에 대해 집계 (누락 값 0 처리)
# fill_value=0: 누락 값 0 처리
pt = df.pivot_table(
    index=['구분', '유형'],
    columns='크기',
    values='수량',
    aggfunc='sum',
    fill_value=0
)
pt
# Out:
# 크기     대형  소형
# 구분 유형
# 가전 일반   4   5
#    특수   7   6
# 전자 일반   4   1
#    특수   0   6

# %%
# 여러 열에 대해 각기 다른 집계 함수 적용
# aggfunc: dictionary 받을 수 있음
pt = df.pivot_table(
    index=['구분', '크기'],
    values=['수량', '금액'],
    aggfunc={'수량': "mean", '금액': "mean"}
)
pt
# Out:
#              금액        수량
# 구분 크기
# 가전 대형  7.500000  5.500000
#    소형  8.500000  5.500000
# 전자 대형  4.500000  2.000000
#    소형  4.333333  2.333333

# %%
# 하나의 열에 대해 여러 집계 함수를 동시에 적용
pt = df.pivot_table(
    index=['구분', '크기'],
    values=['수량', '금액'],
    aggfunc={'수량': "mean", '금액': ["min", "max", "mean"]}
)
pt
# Out:
#        금액                      수량
#       max      mean min      mean
# 구분 크기
# 가전 대형   9  7.500000   6  5.500000
#    소형   9  8.500000   8  5.500000
# 전자 대형   5  4.500000   4  2.000000
#    소형   6  4.333333   2  2.333333

# %%
pt.reset_index()
# Out:
#    구분  크기  금액                      수량
#           max      mean min      mean
# 0  가전  대형   9  7.500000   6  5.500000
# 1  가전  소형   9  8.500000   8  5.500000
# 2  전자  대형   5  4.500000   4  2.000000
# 3  전자  소형   6  4.333333   2  2.333333

# %% [markdown]
# ## Section21.Quiz

# %%
# 데이터 불러오기
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "메뉴":['아메리카노', '카페라떼', '에스프레소', '카페모카', '바닐라라떼'],
    "가격":[4500, 5000, 4000, 5900, 5300],
    "칼로리":[10, 110, np.nan, 210, np.nan],
    "원산지":['과테말라','브라질','과테말라', np.nan, np.nan]
})
df
# Out:
#       메뉴    가격    칼로리   원산지
# 0  아메리카노  4500   10.0  과테말라
# 1   카페라떼  5000  110.0   브라질
# 2  에스프레소  4000    NaN  과테말라
# 3   카페모카  5900  210.0   NaN
# 4  바닐라라떼  5300    NaN   NaN

# %% [markdown]
# **1. '칼로리' 컬럼 결측치는 칼로리 데이터 중 최소값으로 결측치를 채우시오**

# %%
min_cal = df['칼로리'].min()
df['칼로리'] = df['칼로리'].fillna(min_cal)
df
# Out:
#       메뉴    가격    칼로리   원산지
# 0  아메리카노  4500   10.0  과테말라
# 1   카페라떼  5000  110.0   브라질
# 2  에스프레소  4000   10.0  과테말라
# 3   카페모카  5900  210.0   NaN
# 4  바닐라라떼  5300   10.0   NaN

# %% [markdown]
# **2. '원산지' 컬럼 결측치는 원두 데이터 중 최빈값으로 결측치를 채우시오**

# %%
f = df['원산지'].mode()[0]
df['원산지'] = df['원산지'].fillna(f)
df
# Out:
#       메뉴    가격    칼로리   원산지
# 0  아메리카노  4500   10.0  과테말라
# 1   카페라떼  5000  110.0   브라질
# 2  에스프레소  4000   10.0  과테말라
# 3   카페모카  5900  210.0  과테말라
# 4  바닐라라떼  5300   10.0  과테말라

# %% [markdown]
# **3. 가격이 5000 이상인 데이터의 수를 구하시오**

# %%
cond = df['가격'] >= 5000
len(df[cond]) # 또는 sum(cond)
# Out:
# 3

# %% [markdown]
# **4. ’이벤트가’ 컬럼을 만들고 기존 가격에서 50% 할인된 가격을 채우시오**

# %%
df['이벤트가'] = df['가격'] * 0.5
df
# Out:
#       메뉴    가격    칼로리   원산지    이벤트가
# 0  아메리카노  4500   10.0  과테말라  2250.0
# 1   카페라떼  5000  110.0   브라질  2500.0
# 2  에스프레소  4000   10.0  과테말라  2000.0
# 3   카페모카  5900  210.0  과테말라  2950.0
# 4  바닐라라떼  5300   10.0  과테말라  2650.0

# %% [markdown]
# **5. '칼로리' 컬럼을 삭제하시오**
# -

# %%
df = df.drop('칼로리', axis=1)
df
# Out:
#       메뉴    가격   원산지    이벤트가
# 0  아메리카노  4500  과테말라  2250.0
# 1   카페라떼  5000   브라질  2500.0
# 2  에스프레소  4000  과테말라  2000.0
# 3   카페모카  5900  과테말라  2950.0
# 4  바닐라라떼  5300  과테말라  2650.0

# %% [markdown]
# **6. 앞에서부터 3개의 데이터만 선택하시오(loc 활용)**

# %%
df.loc[:2]
# Out:
#       메뉴    가격   원산지    이벤트가
# 0  아메리카노  4500  과테말라  2250.0
# 1   카페라떼  5000   브라질  2500.0
# 2  에스프레소  4000  과테말라  2000.0

# %% [markdown]
# **7. 앞에서부터 3개의 데이터만 선택하시오(iloc 활용)**

# %%
df.iloc[:3]
# Out:
#       메뉴    가격   원산지    이벤트가
# 0  아메리카노  4500  과테말라  2250.0
# 1   카페라떼  5000   브라질  2500.0
# 2  에스프레소  4000  과테말라  2000.0

# %% [markdown]
# **8. 주어진 데이터(df)에서 아래 값을 loc를 활용해 데이터 프레임으로 출력하시오**
# - 카페라떼	5000
# - 에스프레소 4000

# %%
# loc
df.loc[1:2, :'가격']
# Out:
#       메뉴    가격
# 1   카페라떼  5000
# 2  에스프레소  4000

# %% [markdown]
# **9. 주어진 데이터(df)에서 아래 값을 iloc를 활용해 데이터 프레임으로 출력하시오**
# - 카페라떼	5000
# - 에스프레소 4000

# %%
# iloc
df.iloc[1:3, :2]
# Out:
#       메뉴    가격
# 1   카페라떼  5000
# 2  에스프레소  4000

# %% [markdown]
# **10. 메뉴 중 가격이 가장 비싼 순으로 정렬해 상위 3개 값을 구하시오**

# %%
df = df.sort_values('가격', ascending=False)
df.iloc[:3]
# Out:
#       메뉴    가격   원산지    이벤트가
# 3   카페모카  5900  과테말라  2950.0
# 4  바닐라라떼  5300  과테말라  2650.0
# 1   카페라떼  5000   브라질  2500.0
